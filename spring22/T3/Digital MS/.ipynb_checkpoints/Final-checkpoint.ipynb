# %% [markdown]
# # Digital Marketing Final

# %% [markdown]
# ## init

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.ExcelFile("CompleteData.xlsm")
df.sheet_names
# Out:
# ['Conversion Rate Raw',
#  'Social - Medium Raw',
#  'Social - Medium - Pivot',
#  'SMAU',
#  'SMID',
#  'Channels - Pivot',
#  'CAU',
#  'CID',
#  'Channel Raw']

# %%
Conversion_Rate_Raw = df.parse("Conversion Rate Raw")
Social_Medium_Raw = df.parse("Social - Medium Raw")
Social_Medium_Pivot_AU = df.parse("SMAU")
Social_Medium_Pivot_ID = df.parse("SMID")
Channels_Pivot_AU = df.parse("CAU")
Channels_Pivot_ID = df.parse("CID")
Channel_Raw = df.parse("Channel Raw")
Channel_Raw
# Out:
#     Country Saras  Channel Groupping  Month of Year   Users  New Users  \
# 0        ID                   Social         202106   48553      33324
# 1        ID                   Social         202107   14072       7550
# 2        ID                   Social         202108  125026     102289
# 3        ID                   Social         202109  284006     240588
# 4        ID                   Social         202110  859964     804860
# ..      ...                      ...            ...     ...        ...
# 212      AU                  (Other)         202201    6909       5557
# 213      AU                  (Other)         202202    4466       3313
# 214      AU                  (Other)         202203   20019      16952
# 215      AU                  (Other)         202204   15390      12474
# 216      AU                  (Other)         202205   17452      14133
#
#      Sessions  Bounce Rate  Pages / Session  Avg. Session Duration  \
# 0       72044     0.512506         3.868802             143.288865
# 1       23714     0.488150         4.402758             159.286202
# 2      146136     0.617165         3.188845              91.853931
# 3      351023     0.733502         2.609883              75.083402
# 4     1103039     0.845034         1.324728              45.983834
# ..        ...          ...              ...                    ...
# 212      9062     0.511300         3.260000               0.001181
# 213      6266     0.386200         3.950000               0.001562
# 214     28607     0.373000         4.000000               0.001551
# 215     21372     0.460900         3.930000               0.001609
# 216     25057     0.376900         4.460000               0.001852
#
#     Ecommerce Conversion Rate  Transactions       Revenue
# 0                    0.002374           171     109475621
# 1                    0.004512           107      60522955
# 2                    0.002347           343     221458620
# 3                    0.002288           803     450904460
# 4                    0.000028            31      33086100
# ..                        ...           ...           ...
# 212                    0.0277           251   A$36,275.57
# 213                    0.0354           222   A$34,482.48
# 214                    0.0305           872  A$132,336.27
# 215                    0.0392           837  A$130,581.50
# 216                    0.0446          1118  A$170,378.76
#
# [217 rows x 12 columns]

# %% [markdown]
# # Cleaning

# %%
import datetime
Conversion_Rate_Raw["Month of Year1"] = Conversion_Rate_Raw["Month of Year"].apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m'))
Conversion_Rate_Raw_ID = Conversion_Rate_Raw.loc[Conversion_Rate_Raw["Country"]=="ID"]
Conversion_Rate_Raw_AU = Conversion_Rate_Raw.loc[Conversion_Rate_Raw["Country"]=="AU"]
print(Conversion_Rate_Raw_ID.shape)
Conversion_Rate_Raw_ID.head(2)
# Out:
# (12, 8)
#    Country  Month of Year    Users  Sessions  Transactions  \
# 12      ID         202110  1367712   1781296           232
# 13      ID         202204  1352638   2076625           341
#
#     Ecommerce Conversion Rate Transactions per User Month of Year1
# 12                     0.0001                0.0002     2021-10-01
# 13                     0.0002                0.0003     2022-04-01

# %%
Social_Medium_Raw["Revenue1"] = Social_Medium_Raw["Revenue"].apply(lambda x: '{:.2f}'.format(float(x[2:].replace(",", ""))).rstrip("0") if type(x) == str else x)
Social_Medium_Raw["Month of Year1"] = Social_Medium_Raw["Month of Year"].apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m'))
Social_Medium_Raw_ID = Social_Medium_Raw.loc[Social_Medium_Raw["Country"]=="ID"]
Social_Medium_Raw_AU = Social_Medium_Raw.loc[Social_Medium_Raw["Country"]=="AU"]
print(Social_Medium_Raw_AU.shape)
Social_Medium_Raw_AU.head(2)
# Out:
# (148, 14)
#     Country    Source  Month of Year  Users  New Users  Sessions  Bounce Rate  \
# 247      AU    TikTok         202110  68633      69378     71455       0.9708
# 248      AU  Facebook         202109  42376      39970     62290       0.5756
#
#      Pages / Session  Avg. Session Duration Ecommerce Conversion Rate  \
# 247             1.07               0.000069                    <0.01%
# 248             2.94               0.001042                    0.0105
#
#      Transactions      Revenue  Revenue1 Month of Year1
# 247             3     A$195.87    195.87     2021-10-01
# 248           654  A$71,506.81  71506.81     2021-09-01

# %%
Channel_Raw["Revenue1"] = Channel_Raw["Revenue"].apply(lambda x: '{:.2f}'.format(float(x[2:].replace(",", ""))).rstrip("0") if type(x) == str else x)
Channel_Raw["Month of Year1"] = Channel_Raw["Month of Year"].apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m'))
Channel_Raw_ID = Channel_Raw.loc[Channel_Raw["Country"]=="ID"]
Channel_Raw_AU = Channel_Raw.loc[Channel_Raw["Country"]=="AU"]
print(Channel_Raw_ID.shape)
Channel_Raw_ID.head(2)
# Out:
# (129, 14)
#   Country Saras  Channel Groupping  Month of Year  Users  New Users  Sessions  \
# 0      ID                   Social         202106  48553      33324     72044
# 1      ID                   Social         202107  14072       7550     23714
#
#    Bounce Rate  Pages / Session  Avg. Session Duration  \
# 0     0.512506         3.868802             143.288865
# 1     0.488150         4.402758             159.286202
#
#   Ecommerce Conversion Rate  Transactions    Revenue   Revenue1 Month of Year1
# 0                  0.002374           171  109475621  109475621     2021-06-01
# 1                  0.004512           107   60522955   60522955     2021-07-01

# %%
print(Social_Medium_Pivot_AU.head(2),"\n")
print(Social_Medium_Pivot_ID.head(2))
# Out:
#      Source  Sum of Sessions  Sum of Transactions
# 0  Facebook           416054                 1228
# 1    TikTok           109994                   10
#
#      Source  Sum of Sessions  Sum of Transactions
# 0  Facebook          2670730                  448
# 1  whatsapp           472217                 1782

# %%
print(Channels_Pivot_AU.head(2),"\n")
print(Channels_Pivot_ID.head(2))
# Out:
#   Saras  Channel Groupping  Sum of Sessions  Sum of Transactions
# 0              Paid Search          1153284                19846
# 1           Organic Search          1080631                 9369
#
#   Saras  Channel Groupping  Sum of Sessions  Sum of Transactions
# 0                  Display          4262422                 1030
# 1                   Social          3745847                 2639

# %% [markdown]
# # Feature Engineering

# %%
Channel_Raw_ID
# Out:
#     Country Saras  Channel Groupping  Month of Year   Users  New Users  \
# 0        ID                   Social         202106   48553      33324
# 1        ID                   Social         202107   14072       7550
# 2        ID                   Social         202108  125026     102289
# 3        ID                   Social         202109  284006     240588
# 4        ID                   Social         202110  859964     804860
# ..      ...                      ...            ...     ...        ...
# 124      ID                  (Other)         202201    4467       2528
# 125      ID                  (Other)         202202    3004       1723
# 126      ID                  (Other)         202203   10357       7347
# 127      ID                  (Other)         202204  378289     362204
# 128      ID                  (Other)         202205   91174      84096
#
#      Sessions  Bounce Rate  Pages / Session  Avg. Session Duration  \
# 0       72044     0.512506         3.868802             143.288865
# 1       23714     0.488150         4.402758             159.286202
# 2      146136     0.617165         3.188845              91.853931
# 3      351023     0.733502         2.609883              75.083402
# 4     1103039     0.845034         1.324728              45.983834
# ..        ...          ...              ...                    ...
# 124      7928     0.757442         2.097629              66.431382
# 125      4344     0.623389         2.328039              73.978361
# 126     14825     0.374098         1.915750              91.042428
# 127    504245     0.752325         1.449611              38.207746
# 128    103845     0.695296         1.628697              46.455978
#
#     Ecommerce Conversion Rate  Transactions    Revenue   Revenue1  \
# 0                    0.002374           171  109475621  109475621
# 1                    0.004512           107   60522955   60522955
# 2                    0.002347           343  221458620  221458620
# 3                    0.002288           803  450904460  450904460
# 4                    0.000028            31   33086100   33086100
# ..                        ...           ...        ...        ...
# 124                  0.004667            37   30969960   30969960
# 125                  0.001611             7    6329200    6329200
# 126                  0.001079            16   16828025   16828025
# 127                  0.000034            17   21092465   21092465
# 128                  0.000058             6    6799000    6799000
#
#     Month of Year1
# 0       2021-06-01
# 1       2021-07-01
# 2       2021-08-01
# 3       2021-09-01
# 4       2021-10-01
# ..             ...
# 124     2022-01-01
# 125     2022-02-01
# 126     2022-03-01
# 127     2022-04-01
# 128     2022-05-01
#
# [129 rows x 14 columns]

# %%
plt.plot(Channel_Raw_ID["Month of Year1"][:12], Channel_Raw_ID["Revenue1"][:12])
