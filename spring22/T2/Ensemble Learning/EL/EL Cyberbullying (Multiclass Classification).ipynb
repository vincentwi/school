# %% [markdown]
# # Ensemble Learning for Cyberbullying Detection

# %%
#Importing libraries and dependencies 
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from catboost import Pool, CatBoostClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score


import shap


from hyperopt import fmin, hp, tpe

import matplotlib.pyplot as plt
import seaborn as sns

#Set display options to None 
pd.options.display.max_columns = None
pd.options.display.max_rows = None

#Load in the dataset 
dataset = pd.read_csv('../input/cyberbullying/all_features.csv', index_col=0)

# #Create X and y partition 
X = dataset.drop('cyberbullying_type',axis=1)
y = dataset['cyberbullying_type']

# Perform train-test split on the dataset 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=40)

train_df = dataset.sample(frac=1,random_state=1).reset_index(drop=True)
train_x = list(train_df.drop(['cyberbullying_type'], axis=1).columns)


def CV_catboost(X_train,y_train,X_test,y_test):

    y_train = np.transpose(np.array(y_train)).ravel()
    y_test = np.transpose(np.array(y_test)).ravel()

    # Training
    train_dataset = Pool(data=X_train,label=y_train)
    #Test
    eval_dataset = Pool(data=X_test,label=y_test)

    # set parameters of model
    model = CatBoostClassifier(
        iterations=10000,
        random_strength=1, #set to one to prevent overfitting
        depth=6, #relatively low to prevent overfitting
        l2_leaf_reg=2, #from grid search
        border_count=20, #from grid search
        learning_rate=0.01,
        rsm=1, #from grid search
        loss_function='MultiClass',
        eval_metric='Accuracy',
        boosting_type = 'Plain',
        silent=True,
        task_type="GPU")

    # fit model and make predictions for cross-validation 
    # model.fit(train_dataset, plot=True, eval_set=eval_dataset)
    model.fit(train_dataset,verbose_eval=100,eval_set=eval_dataset,plot=True)

    #Make prediction on out-of-sample set 
    y_pred = model.predict(X_test)  # change to test_x if for real test

    f1 = f1_score(y_test, y_pred, average='macro')
    accuracy = accuracy_score(y_test, y_pred)

    report = classification_report(y_test, y_pred)
    print(report)

    return [f1, accuracy]

# %%
x_cols = train_x

y_col = ['cyberbullying_type']

nb_splits = 5
splits =np.array_split(train_df, nb_splits)

# run the CV_catboost in a loop

f1_all_catboost = [0,0,0,0,0]
accuracy_all_catboost = [0,0,0,0,0]
scores_catboost = [0,0,0,0,0]
for i in range(nb_splits):
    not_test_indices = [x for x in range(nb_splits) if x != i]
    temp_df_X_y = (pd.concat([splits[x] for x in not_test_indices],axis=0))
    X_train = temp_df_X_y[x_cols]
    y_train = temp_df_X_y[y_col]
    X_test = splits[i][x_cols]
    y_test = splits[i][y_col]

    scores_catboost[i] = CV_catboost(X_train,y_train,X_test,y_test)

for i in range(len(scores_catboost)):
    f1_all_catboost[i] = scores_catboost[i][0]
    accuracy_all_catboost[i] = scores_catboost[i][1]

print("*"*100)
print("The cross validated f1 score is " + str(np.mean(f1_all_catboost)))
print("The cross validated accuracy is " + str(np.mean(accuracy_all_catboost)))
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.6448248	test: 0.6473425	best: 0.6473425 (0)	total: 11.3ms	remaining: 1m 52s
# 100:	learn: 0.7220402	test: 0.7243946	best: 0.7254429 (99)	total: 964ms	remaining: 1m 34s
# 200:	learn: 0.7454984	test: 0.7516511	best: 0.7516511 (200)	total: 1.91s	remaining: 1m 33s
# 300:	learn: 0.7715776	test: 0.7772303	best: 0.7772303 (299)	total: 3.2s	remaining: 1m 43s
# 400:	learn: 0.7884308	test: 0.7941084	best: 0.7941084 (400)	total: 4.29s	remaining: 1m 42s
# 500:	learn: 0.7997798	test: 0.8022854	best: 0.8024950 (496)	total: 5.22s	remaining: 1m 38s
# 600:	learn: 0.8079574	test: 0.8099381	best: 0.8100430 (598)	total: 6.15s	remaining: 1m 36s
# 700:	learn: 0.8127015	test: 0.8130831	best: 0.8131880 (684)	total: 7.09s	remaining: 1m 34s
# 800:	learn: 0.8167379	test: 0.8153895	best: 0.8154943 (791)	total: 8.02s	remaining: 1m 32s
# 900:	learn: 0.8191492	test: 0.8167523	best: 0.8170668 (898)	total: 9.66s	remaining: 1m 37s
# 1000:	learn: 0.8218489	test: 0.8187441	best: 0.8192683 (996)	total: 10.6s	remaining: 1m 35s
# 1100:	learn: 0.8245485	test: 0.8210504	best: 0.8217843 (1085)	total: 11.6s	remaining: 1m 33s
# 1200:	learn: 0.8268026	test: 0.8230422	best: 0.8234616 (1175)	total: 12.6s	remaining: 1m 32s
# 1300:	learn: 0.8294498	test: 0.8251389	best: 0.8252437 (1297)	total: 14s	remaining: 1m 33s
# 1400:	learn: 0.8311273	test: 0.8260824	best: 0.8261872 (1398)	total: 14.9s	remaining: 1m 31s
# 1500:	learn: 0.8330931	test: 0.8262921	best: 0.8269211 (1433)	total: 15.9s	remaining: 1m 30s
# 1600:	learn: 0.8341677	test: 0.8272356	best: 0.8274452 (1597)	total: 16.9s	remaining: 1m 28s
# 1700:	learn: 0.8356617	test: 0.8278646	best: 0.8279694 (1696)	total: 18s	remaining: 1m 27s
# 1800:	learn: 0.8368673	test: 0.8282839	best: 0.8287032 (1784)	total: 18.9s	remaining: 1m 26s
# 1900:	learn: 0.8382303	test: 0.8293322	best: 0.8295419 (1878)	total: 19.9s	remaining: 1m 24s
# 2000:	learn: 0.8396718	test: 0.8297515	best: 0.8303805 (1971)	total: 20.9s	remaining: 1m 23s
# 2100:	learn: 0.8409824	test: 0.8301709	best: 0.8306950 (2048)	total: 21.9s	remaining: 1m 22s
# 2200:	learn: 0.8424239	test: 0.8303805	best: 0.8306950 (2048)	total: 22.9s	remaining: 1m 21s
# 2300:	learn: 0.8438393	test: 0.8304854	best: 0.8309047 (2211)	total: 24.1s	remaining: 1m 20s
# 2400:	learn: 0.8455429	test: 0.8306950	best: 0.8310095 (2391)	total: 25.3s	remaining: 1m 19s
# 2500:	learn: 0.8464079	test: 0.8305902	best: 0.8310095 (2391)	total: 26.3s	remaining: 1m 18s
# 2600:	learn: 0.8476660	test: 0.8309047	best: 0.8311144 (2545)	total: 27.3s	remaining: 1m 17s
# 2700:	learn: 0.8490027	test: 0.8316385	best: 0.8317434 (2699)	total: 28.2s	remaining: 1m 16s
# 2800:	learn: 0.8508112	test: 0.8315337	best: 0.8318482 (2757)	total: 29.2s	remaining: 1m 15s
# 2900:	learn: 0.8515975	test: 0.8313240	best: 0.8321627 (2826)	total: 30.2s	remaining: 1m 13s
# 3000:	learn: 0.8529342	test: 0.8321627	best: 0.8321627 (2826)	total: 31.2s	remaining: 1m 12s
# 8500:	learn: 0.8961839	test: 0.8278465	best: 0.8287901 (6408)	total: 1m 35s	remaining: 16.9s
# 8600:	learn: 0.8971274	test: 0.8273223	best: 0.8287901 (6408)	total: 1m 36s	remaining: 15.8s
# 8700:	learn: 0.8977827	test: 0.8271126	best: 0.8287901 (6408)	total: 1m 38s	remaining: 14.7s
# 8800:	learn: 0.8985427	test: 0.8271126	best: 0.8287901 (6408)	total: 1m 39s	remaining: 13.6s
# 8900:	learn: 0.8992242	test: 0.8266932	best: 0.8287901 (6408)	total: 1m 40s	remaining: 12.4s
# 9000:	learn: 0.8997746	test: 0.8263787	best: 0.8287901 (6408)	total: 1m 41s	remaining: 11.3s
# 9100:	learn: 0.9004560	test: 0.8263787	best: 0.8287901 (6408)	total: 1m 42s	remaining: 10.2s
# 9200:	learn: 0.9010851	test: 0.8260642	best: 0.8287901 (6408)	total: 1m 44s	remaining: 9.04s
# 9300:	learn: 0.9018714	test: 0.8256448	best: 0.8287901 (6408)	total: 1m 45s	remaining: 7.91s
# 9400:	learn: 0.9026314	test: 0.8256448	best: 0.8287901 (6408)	total: 1m 46s	remaining: 6.8s
# 9500:	learn: 0.9033653	test: 0.8251206	best: 0.8287901 (6408)	total: 1m 48s	remaining: 5.68s
# 9600:	learn: 0.9038633	test: 0.8253303	best: 0.8287901 (6408)	total: 1m 49s	remaining: 4.55s
# 9700:	learn: 0.9044137	test: 0.8251206	best: 0.8287901 (6408)	total: 1m 50s	remaining: 3.41s
# 9800:	learn: 0.9055669	test: 0.8249109	best: 0.8287901 (6408)	total: 1m 52s	remaining: 2.27s
# 9900:	learn: 0.9059863	test: 0.8247012	best: 0.8287901 (6408)	total: 1m 53s	remaining: 1.13s
# 9999:	learn: 0.9066677	test: 0.8248060	best: 0.8287901 (6408)	total: 1m 54s	remaining: 0us
# bestTest = 0.8287901027
# bestIteration = 6408
# Shrink model to first 6409 iterations.
#                      precision    recall  f1-score   support
#
#                 age       0.98      0.97      0.98      1619
#           ethnicity       0.98      0.94      0.96      1603
#              gender       0.89      0.82      0.85      1587
#   not_cyberbullying       0.59      0.56      0.58      1585
# other_cyberbullying       0.62      0.73      0.67      1585
#            religion       0.95      0.95      0.95      1559
#
#            accuracy                           0.83      9538
#           macro avg       0.84      0.83      0.83      9538
#        weighted avg       0.84      0.83      0.83      9538
#
# ****************************************************************************************************
# The cross validated f1 score is 0.8334764318494005
# The cross validated accuracy is 0.8317327651450246

# %% [markdown]
# # CatBoost Prediction

# %%
df = dataset.sample(frac=1,random_state=1).reset_index(drop=True)

section = round(len(df)*8/10)
train_df = df.iloc[:section]
test_df = df.iloc[section:]

train_cols_x = list(train_df.drop(['cyberbullying_type'], axis=1).columns)
test_cols_x = list(test_df.drop(['cyberbullying_type'], axis=1).columns)


train_x = train_df[train_cols_x]
test_x = test_df[test_cols_x]

train_y = train_df["cyberbullying_type"]
test_y = test_df["cyberbullying_type"]
test_y = test_y.reset_index(drop=True)
test_x = test_x.reset_index(drop=True)


train_y = np.transpose(np.array(train_y)).ravel()
test_y = np.transpose(np.array(test_y)).ravel()

#define dataset used to train the model
train_dataset = Pool(data=train_x,
                     label=train_y,
                     )

#define dataset used to test the model
eval_dataset = Pool(data=test_x)

#set model parameters
model = CatBoostClassifier(
        iterations=10000,
        random_strength=1, #set to one to prevent overfitting
        depth=6, #relatively low to prevent overfitting
        l2_leaf_reg=2, #from grid search
        border_count=20, #from grid search
        learning_rate=0.01,
        rsm=1, #from grid search
        loss_function='MultiClass',
        eval_metric='Accuracy',
        boosting_type = 'Plain',
        silent=True,
        task_type="GPU")


model.fit(train_dataset, plot=True)

importances = model.feature_importances_


df_feat_imp = pd.DataFrame()
df_feat_imp['Features'] = train_cols_x
df_feat_imp['Importance'] = importances.tolist()
df_feat_imp = df_feat_imp.sort_values(by='Importance',ascending=False)
print(df_feat_imp.head(10))
# df_feat_imp.to_csv("feature_importance_combo.csv")

y_pred = model.predict(test_x)



f1 = f1_score(test_y, y_pred, average='macro')
accuracy = accuracy_score(test_y, y_pred)
print("f1 score is " + str(f1))
print("accuracy is " + str(accuracy))
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
#                  Features  Importance
# 0    characters per tweet    7.031804
# 143                school    4.844225
# 64                      @    4.834997
# 118                 bully    4.758607
# 4          nb_capitalized    4.309246
# 83                 nigger    3.316220
# 109                 idiot    3.139793
# 34                      i    2.575371
# 125                muslim    2.417679
# 91                muslims    2.241238
# f1 score is 0.8267433517741227
# accuracy is 0.8250157265674145

# %% [markdown]
# # Random Forests

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import classification_report, f1_score
from sklearn.compose import ColumnTransformer

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import skew

## reading in the training dataset - there are various training sets to consider
## based on how



## extract the column names from the dataframe.
train_x_columns = list(X.columns)


#Creating a Categorical Encoder pipeline 
c_encoder = LabelEncoder()
y = c_encoder.fit_transform(y) #Y is categorical, so it needs to be converted

## splitting the training data into a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=40)

rf = RandomForestClassifier(criterion = "gini", max_depth=25, min_samples_leaf = 1, n_estimators=300, 
                            random_state=0, class_weight = 'balanced_subsample', bootstrap=True, n_jobs=-1)

## fitting the model to the train data split
fit_model = True
if fit_model:
    print('Training model')
    rf.fit(X_train, y_train)

# ## using the model to predict the y test values using the test data
print('Predicting on test set now')
y_pred = rf.predict(X_test)

## Test scores
print(classification_report(y_test, y_pred))
print('F1 score:',round(f1_score(y_test,y_pred, average = 'macro'),3))

runCV = True
## run cross validation on fitted model
scoring = {'acc': 'accuracy',
           'f1_macro': 'f1_macro'}
if runCV:
    scores = cross_validate(rf, X_train, y_train, cv=5, scoring=scoring)
    #print(scores)
    #print(np.average(scores))
    print("-----------------------------------")
    print("CV Accuracy:", round(np.average(scores['test_acc']),4))
    print("CV f1 Score:", round(np.average(scores['test_f1_macro']),4))
    print("-----------------------------------")


## grid search for random forest.
gs = True
if gs:
    print('Starting grid search for optimal parameters')
    rf_gs = RandomForestClassifier()
    param_grid = {
        'class_weight': ["balanced",'balanced_subsample'],
        'max_depth': [10,20,30],
        'n_estimators': [100,200],
        'min_samples_leaf': [1,2,4],
    }
    
    grid_search = GridSearchCV(rf_gs, param_grid, cv=5, scoring='f1_macro', verbose = 10,n_jobs = -1)
    grid_search.fit(X_train, y_train)

    print(("best RF from grid search: %.3f"
           % grid_search.score(X_train, y_train)))
    
print('Grid Search best parameters: {}'.format(grid_search.best_params_))

# code to extract the most important features
get_imp = True
if get_imp:    
    importances = rf.steps[1][1].feature_importances_
    feature_names = rf['preprocessor'].transformers_[1][1]['onehot']\
                   .get_feature_names(categorical_features)               
    df_feat_imp = pd.DataFrame()
    df_feat_imp['Features'] = numeric_features + list(feature_names)
    df_feat_imp['Importance'] = importances.tolist()
    df_feat_imp = df_feat_imp.sort_values(by='Importance',ascending=False)
    print(df_feat_imp.head(10))
    df_feat_imp.to_csv("feature_importance.csv")
# Out:
# Training model
# Predicting on test set now
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1582
#            1       0.99      0.90      0.94      1628
#            2       0.93      0.79      0.85      1593
#            3       0.57      0.54      0.56      1569
#            4       0.55      0.73      0.63      1551
#            5       0.96      0.94      0.95      1616
#
#     accuracy                           0.81      9539
#    macro avg       0.83      0.81      0.82      9539
# weighted avg       0.83      0.81      0.82      9539
#
# F1 score: 0.818
# -----------------------------------
# CV Accuracy: 0.8078
# CV f1 Score: 0.8132
# -----------------------------------
# Starting grid search for optimal parameters
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5; 1/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 1/5; 1/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.786 total time=   4.6s
# [CV 3/5; 1/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 3/5; 1/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.768 total time=   4.4s
# [CV 5/5; 1/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 5/5; 1/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.773 total time=   4.7s
# [CV 2/5; 2/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 2/5; 2/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.777 total time=   9.6s
# [CV 4/5; 2/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 4/5; 2/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.782 total time=   8.7s
# [CV 1/5; 3/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100
# [CV 1/5; 3/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=0.779 total time=   4.7s
# [CV 2/5; 3/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100
# [CV 2/5; 3/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=0.778 total time=   4.3s
# [CV 4/5; 3/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100
# [CV 4/5; 3/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=0.777 total time=   4.6s
# [CV 1/5; 4/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200
# [CV 1/5; 4/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200;, score=0.786 total time=   9.7s
# [CV 3/5; 4/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200
# [CV 3/5; 4/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200;, score=0.777 total time=   8.7s
# [CV 5/5; 4/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200
# [CV 5/5; 4/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200;, score=0.780 total time=   9.0s
# [CV 3/5; 5/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 3/5; 5/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.774 total time=   4.5s
# [CV 5/5; 5/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 5/5; 5/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.782 total time=   4.4s
# [CV 2/5; 6/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 2/5; 6/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.781 total time=   9.4s
# [CV 4/5; 6/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 4/5; 6/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.779 total time=   8.9s
# [CV 1/5; 7/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100
# [CV 1/5; 7/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.819 total time=   7.1s
# [CV 3/5; 7/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100
# [CV 3/5; 7/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.811 total time=   7.6s
# [CV 5/5; 7/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100
# [CV 5/5; 7/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.813 total time=   8.5s
# [CV 2/5; 8/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200
# [CV 2/5; 8/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.818 total time=  14.9s
# [CV 4/5; 8/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200
# [CV 4/5; 8/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.815 total time=  16.0s
# [CV 1/5; 9/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 1/5; 9/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.820 total time=   7.1s
# [CV 2/5; 9/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 2/5; 9/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.816 total time=   7.4s
# [CV 4/5; 9/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 4/5; 9/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.816 total time=   7.3s
# [CV 1/5; 10/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 1/5; 10/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.822 total time=  15.0s
# [CV 3/5; 10/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 3/5; 10/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.815 total time=  14.3s
# [CV 5/5; 10/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 5/5; 10/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.811 total time=  15.3s
# [CV 2/5; 11/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100
# [CV 2/5; 11/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.814 total time=   6.8s
# [CV 4/5; 11/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100
# [CV 4/5; 11/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.813 total time=   7.2s
# [CV 1/5; 12/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200
# [CV 1/5; 12/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.820 total time=  14.3s
# [CV 3/5; 12/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200
# [CV 3/5; 12/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.817 total time=  14.4s
# [CV 5/5; 12/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200
# [CV 5/5; 12/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.812 total time=  14.8s
# [CV 3/5; 13/36] START class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=100
# [CV 3/5; 13/36] END class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.810 total time=  10.0s
# [CV 5/5; 13/36] START class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=100
# [CV 5/5; 13/36] END class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.810 total time=   9.2s
# [CV 2/5; 14/36] START class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=200
# [CV 2/5; 14/36] END class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.811 total time=  18.6s
# [CV 4/5; 14/36] START class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=200
# [CV 4/5; 14/36] END class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.808 total time=  19.6s
# [CV 1/5; 15/36] START class_weight=balanced, max_depth=30, min_samples_leaf=2, n_estimators=100
# [CV 1/5; 15/36] END class_weight=balanced, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.813 total time=   8.7s
# [CV 2/5; 15/36] START class_weight=balanced, max_depth=30, min_samples_leaf=2, n_estimators=100
# [CV 2/5; 15/36] END class_weight=balanced, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.810 total time=   9.2s[CV 2/5; 1/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 2/5; 1/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.778 total time=   4.7s
# [CV 4/5; 1/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 4/5; 1/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.779 total time=   4.5s
# [CV 1/5; 2/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 1/5; 2/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.785 total time=   9.2s
# [CV 3/5; 2/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 3/5; 2/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.776 total time=   9.7s
# [CV 5/5; 2/36] START class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 5/5; 2/36] END class_weight=balanced, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.772 total time=   9.2s
# [CV 3/5; 3/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100
# [CV 3/5; 3/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=0.773 total time=   4.4s
# [CV 5/5; 3/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100
# [CV 5/5; 3/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=0.770 total time=   4.8s
# [CV 2/5; 4/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200
# [CV 2/5; 4/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200;, score=0.783 total time=   9.9s
# [CV 4/5; 4/36] START class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200
# [CV 4/5; 4/36] END class_weight=balanced, max_depth=10, min_samples_leaf=2, n_estimators=200;, score=0.778 total time=   8.7s
# [CV 1/5; 5/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 1/5; 5/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.781 total time=   4.6s
# [CV 2/5; 5/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 2/5; 5/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.782 total time=   4.3s
# [CV 4/5; 5/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 4/5; 5/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.783 total time=   4.8s
# [CV 1/5; 6/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 1/5; 6/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.783 total time=   9.5s
# [CV 3/5; 6/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 3/5; 6/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.775 total time=   8.7s
# [CV 5/5; 6/36] START class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 5/5; 6/36] END class_weight=balanced, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.775 total time=   9.2s
# [CV 2/5; 7/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100
# [CV 2/5; 7/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.815 total time=   7.7s
# [CV 4/5; 7/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100
# [CV 4/5; 7/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.814 total time=   8.6s
# [CV 1/5; 8/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200
# [CV 1/5; 8/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.819 total time=  15.0s
# [CV 3/5; 8/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200
# [CV 3/5; 8/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.814 total time=  15.6s
# [CV 5/5; 8/36] START class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200
# [CV 5/5; 8/36] END class_weight=balanced, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.812 total time=  14.9s
# [CV 3/5; 9/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 3/5; 9/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.809 total time=   7.2s
# [CV 5/5; 9/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 5/5; 9/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.811 total time=   8.0s
# [CV 2/5; 10/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 2/5; 10/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.817 total time=  15.1s
# [CV 4/5; 10/36] START class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 4/5; 10/36] END class_weight=balanced, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.815 total time=  14.7s
# [CV 1/5; 11/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100
# [CV 1/5; 11/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.819 total time=   7.9s
# [CV 3/5; 11/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100
# [CV 3/5; 11/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=   6.8s
# [CV 5/5; 11/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100
# [CV 5/5; 11/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=   7.3s
# [CV 2/5; 12/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200
# [CV 2/5; 12/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.817 total time=  14.9s
# [CV 4/5; 12/36] START class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200
# [CV 4/5; 12/36] END class_weight=balanced, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.815 total time=  15.1s
# [CV 1/5; 13/36] START class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=100
# [CV 1/5; 13/36] END class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.810 total time=   9.9s
# [CV 2/5; 13/36] START class_weight=balanced, max_depth=30, min_samples_leaf=1, n_estimators=100
# [CV
36] END class_weight=balanced, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.809 total time=  17.8s
# [CV 5/5; 16/36] START class_weight=balanced, max_depth=30, min_samples_leaf=2, n_estimators=200
# [CV 5/5; 16/36] END class_weight=balanced, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.808 total time=  18.5s
# [CV 3/5; 17/36] START class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=100
# [CV 3/5; 17/36] END class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.811 total time=   7.7s
# [CV 5/5; 17/36] START class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=100
# [CV 5/5; 17/36] END class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.810 total time=   8.0s
# [CV 2/5; 18/36] START class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=200
# [CV 2/5; 18/36] END class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.815 total time=  16.1s
# [CV 4/5; 18/36] START class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=200
# [CV 4/5; 18/36] END class_weight=balanced, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.812 total time=  16.0s
# [CV 1/5; 19/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 1/5; 19/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.780 total time=   5.9s
# [CV 2/5; 19/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 2/5; 19/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.781 total time=   6.8s
# [CV 4/5; 19/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=100
# [CV 4/5; 19/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=100;, score=0.782 total time=   5.9s
# [CV 1/5; 20/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 1/5; 20/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.785 total time=  11.7s
# [CV 3/5; 20/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 3/5; 20/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.774 total time=  12.6s
# [CV 5/5; 20/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=200
# [CV 5/5; 20/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, n_estimators=200;, score=0.771 total time=  11.6s
# [CV 3/5; 21/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=100
# [CV 3/5; 21/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=0.773 total time=   5.7s
# [CV 5/5; 21/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=100
# [CV 5/5; 21/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=100;, score=0.773 total time=   6.0s
# [CV 2/5; 22/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=200
# [CV 2/5; 22/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=200;, score=0.776 total time=  12.3s
# [CV 4/5; 22/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=200
# [CV 4/5; 22/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, n_estimators=200;, score=0.780 total time=  11.6s
# [CV 1/5; 23/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 1/5; 23/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.785 total time=   6.1s
# [CV 2/5; 23/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 2/5; 23/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.777 total time=   5.6s
# [CV 4/5; 23/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=100
# [CV 4/5; 23/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=100;, score=0.777 total time=   6.7s
# [CV 1/5; 24/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 1/5; 24/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.785 total time=  11.5s
# [CV 3/5; 24/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 3/5; 24/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.773 total time=  11.7s
# [CV 5/5; 24/36] START class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=200
# [CV 5/5; 24/36] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, n_estimators=200;, score=0.780 total time=  12.4s
# [CV 3/5; 25/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=100
# [CV 3/5; 25/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.812 total time=   8.8s
# [CV 5/5; 25/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=100
# [CV 5/5; 25/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.813 total time=   8.7s
# [CV 2/5; 26/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=200
# [CV 2/5; 26/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.815 total time=  18.2s
# [CV 4/5; 26/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=200
# [CV 4/5; 26/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.815 total time=  17.5s
# [CV 1/5; 27/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 1/5; 27/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.819 total time=   9.4s
# [CV 2/5; 27/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 2/5; 27/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.816 total time=   8.2s
# [CV 4/5; 27/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=100
# [CV 4/5; 27/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.812 total time=   8.6s
# [CV 1/5; 28/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 1/5; 28/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.821 total time=  18.4s
# [CV 3/5; 28/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 3/5; 28/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.813 total time=  16.7s
# [CV 5/5; 28/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=200
# [CV 5/5; 28/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.813 total time=  17.8s
# [CV 3/5; 29/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=100best RF from grid search: 0.908
# Grid Search best parameters: {'class_weight': 'balanced_subsample', 'max_depth': 20, 'min_samples_leaf': 1, 'n_estimators': 200}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_33/4165766011.py in <module>
#      82 get_imp = True
#      83 if get_imp:
# ---> 84     importances = rf.steps[1][1].feature_importances_
#      85     feature_names = rf['preprocessor'].transformers_[1][1]['onehot']\
#      86                    .get_feature_names(categorical_features)
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'steps'

# %%
# Out:
# (9539,)
# [CV 3/5; 29/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.810 total time=   8.1s
# [CV 5/5; 29/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=100
# [CV 5/5; 29/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.814 total time=   8.3s
# [CV 2/5; 30/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=200
# [CV 2/5; 30/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.816 total time=  17.0s
# [CV 4/5; 30/36] START class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=200
# [CV 4/5; 30/36] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.815 total time=  16.5s
# [CV 1/5; 31/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=100
# [CV 1/5; 31/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.814 total time=  11.5s
# [CV 2/5; 31/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=100
# [CV 2/5; 31/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.808 total time=  10.5s
# [CV 4/5; 31/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=100
# [CV 4/5; 31/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.804 total time=  10.5s
# [CV 1/5; 32/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=200
# [CV 1/5; 32/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.815 total time=  21.4s
# [CV 3/5; 32/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=200
# [CV 3/5; 32/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.810 total time=  21.4s
# [CV 5/5; 32/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=200
# [CV 5/5; 32/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.809 total time=  21.1s
# [CV 4/5; 33/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=100
# [CV 4/5; 33/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.806 total time=  10.8s
# [CV 1/5; 34/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=200
# [CV 1/5; 34/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.814 total time=  19.8s
# [CV 3/5; 34/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=200
# [CV 3/5; 34/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.810 total time=  20.5s
# [CV 5/5; 34/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=200
# [CV 5/5; 34/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.804 total time=  19.6s
# [CV 3/5; 35/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=100
# [CV 3/5; 35/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.810 total time=  10.0s
# [CV 5/5; 35/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=100
# [CV 5/5; 35/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.810 total time=   9.4s
# [CV 2/5; 36/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=200
# [CV 2/5; 36/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.815 total time=  18.9s
# [CV 4/5; 36/36] START class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=200
# [CV 4/5; 36/36] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.810 total time=  18.4s

# %%
#Training the best RF model with the gridsearch parameters 
rf_best = RandomForestClassifier(criterion = "gini", max_depth=20, min_samples_leaf = 1, n_estimators=200, 
                            random_state=0, class_weight = 'balanced_subsample', bootstrap=True, n_jobs=-1)

rf_best.fit(X_train,y_train)
y_pred = rf_best.predict(X_test)
print(classification_report(y_test, y_pred))
print('F1 score:',round(f1_score(y_test,y_pred, average = 'macro'),3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1582
#            1       0.99      0.90      0.94      1628
#            2       0.94      0.78      0.85      1593
#            3       0.59      0.52      0.55      1569
#            4       0.55      0.78      0.64      1551
#            5       0.96      0.93      0.94      1616
#
#     accuracy                           0.82      9539
#    macro avg       0.83      0.81      0.82      9539
# weighted avg       0.84      0.82      0.82      9539
#
# F1 score: 0.819

# %% [markdown]
# # XGBoost Classifier

# %%
from xgboost import XGBClassifier


#implementation of XGBoost classifier
model = XGBClassifier()
xg_model = model.fit(X_train, np.ravel(y_train))

#cv scores
scores = cross_val_score(xg_model, X_train, np.ravel(y_train), cv=5, scoring='f1_macro')
print(f'CV scores: {scores}')
print(f'Mean CV scores: {np.mean(scores)}')


#Perform prediction 
y_pred_xgboost = xg_model.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
# [02:28:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [02:30:35] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [02:32:19] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [02:34:02] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [02:35:45] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [02:37:29] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CV scores: [0.8329006  0.83050686 0.82689238 0.82503561 0.81925705]
# Mean CV scores: 0.8269185009679015
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1582
#            1       0.99      0.90      0.94      1628
#            2       0.94      0.78      0.85      1593
#            3       0.59      0.52      0.55      1569
#            4       0.55      0.78      0.64      1551
#            5       0.96      0.93      0.94      1616
#
#     accuracy                           0.82      9539
#    macro avg       0.83      0.81      0.82      9539
# weighted avg       0.84      0.82      0.82      9539
