# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/hackathon-data/data-not-localized/'

# %%
df75 = pd.read_csv(path+'mutations_d75.csv')
df77 = pd.read_csv(path+'mutations_d77.csv')
df78 = pd.read_csv(path+'mutations_d78.csv')
df91 = pd.read_csv(path+'mutations_d91.csv')
df92 = pd.read_csv(path+'mutations_d92.csv')
df93 = pd.read_csv(path+'mutations_d93.csv')
df94 = pd.read_csv(path+'mutations_d94.csv')
df95 = pd.read_csv(path+'mutations_d95.csv')

# %%
df_final = pd.concat([df75, df77, df78, df91, df92, df93, df94, df95], ignore_index = True)

# %%
df = df_final.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
df_2 = df[(df.libtypbien == 'UN APPARTEMENT')]

# %%
df_3 = df_2[(df_2.libnatmut == 'Vente') | (df_2.libnatmut == "Vente en l'état futur d'achèvement")]

# %%
df_3
# Out:
#          idmutation  ...      libtypbien
# 0         6539278.0  ...  UN APPARTEMENT
# 1         6660956.0  ...  UN APPARTEMENT
# 5         6550250.0  ...  UN APPARTEMENT
# 7         6671519.0  ...  UN APPARTEMENT
# 8         6840038.0  ...  UN APPARTEMENT
# ...             ...  ...             ...
# 1271562   8596612.0  ...      UNE MAISON
# 1271564   8534218.0  ...      UNE MAISON
# 1271565   8829533.0  ...      UNE MAISON
# 1271566   8830339.0  ...  UN APPARTEMENT
# 1271567   8666786.0  ...      UNE MAISON
#
# [931873 rows x 58 columns]

# %%
import seaborn as sns

sns.scatterplot(df_4['valeurfonc'], df_4['sbati'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_4 = df_3[(df_3.sbati <= 850)]
df_4 = df_4[(df_4.valeurfonc < 1e8)]

# %%
len(df_4)
# Out:
# 931456

# %%
df_4 = df_4[(df_4.valeurfonc != 0)]

# %%
df_4.to_csv("/content/drive/MyDrive/hackathon-data/mutations_filtered.csv")

# %%
len(df_4[df_4.nblot==0] )
# Out:
# 273095
